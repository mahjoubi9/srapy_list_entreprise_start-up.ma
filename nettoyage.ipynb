# %%
import pandas as pd

# %%
import json

with open('allinformation.json', encoding='cp1252') as f:
  data = json.load(f)

data
# Out:
# [{'nameStratup': 'AGYRE TECHNOLOGY SERVICES',
#   'link': 'https://www.start-u.ma/liste-des-startups-au-maroc/agyre-technology-services/',
#   'details': 'AGYRE TECHNOLOGY SERVICES',
#   'website': 'https://www.argyrets.com/?utm_source=start-up.ma'},
#  {'nameStratup': 'AGYRE TECHNOLOGY SERVICES',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/agyre-technology-services/',
#   'details': 'AGYRE TECHNOLOGY SERVICES',
#   'website': 'https://www.argyrets.com/?utm_source=start-up.ma',
#   'phone': 'tel:+212535523161'},
#  {'nameStratup': 'AGYRE TECHNOLOGY SERVICES',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/agyre-technology-services/',
#   'details': 'AGYRE TECHNOLOGY SERVICES',
#   'website': 'https://www.argyrets.com/?utm_source=start-up.ma',
#   'phone': 'tel:+212535523161',
#   'email': 'mailto:contact@argyrets.com'},
#  {'nameStratup': 'AGYRE TECHNOLOGY SERVICES',
# ...

# %%
i=0
for Stratup in data :
  try:
    print(Stratup['email'])
  except:
    i=i+1
  
print(i)
#data[0]['email']
# Out:
# mailto:contact@argyrets.com
# mailto:contact@argyrets.com
# mailto:
# mailto:
# mailto:akoucham.simohammed@gmail.com
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:contact@espacesoutien.com
# mailto:contact@espacesoutien.com
# mailto:amazsneakers@gmail.com
# mailto:amazsneakers@gmail.com
# mailto:bendaanane@amendy.ma
# mailto:bendaanane@amendy.ma
# mailto:annuaire.consultants@gmail.com
# mailto:annuaire.consultants@gmail.com
# mailto:aissaoui.ilyass@yahoo.com
# mailto:aissaoui.ilyass@yahoo.com
# mailto:aissaoui.ilyass@yahoo.com
# mailto:contact@atarec.com
# mailto:contact@atarec.com
# mailto:contact@atlanspace.com
# mailto:contact@atlanspace.com
# mailto:laboratoire@avoircosmetics.com
# mailto:laboratoire@avoircosmetics.com
# mailto:badreddine@benatna.com
# mailto:badreddine@benatna.com
# http://bi3e.com@gmail.com
# http://bi3e.com@gmail.com
# mailto:Biochar.maroc@gmail.com
# ...
