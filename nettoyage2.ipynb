# %%
import pandas as pd

# %%
import json

with open('allinformation2.json', encoding='cp1252') as f:
  data = json.load(f)

data
# Out:
# [{'nameStratup': 'Caronae Systems',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/caronae-systems/',
#   'details': 'Caronae Systems',
#   'website': 'https://www.caronaesystems.com/?utm_source=start-up.ma'},
#  {'nameStratup': 'Caronae Systems',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/caronae-systems/',
#   'details': 'Caronae Systems',
#   'website': 'https://www.caronaesystems.com/?utm_source=start-up.ma',
#   'phone': 'tel:+212606343434'},
#  {'nameStratup': 'Caronae Systems',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/caronae-systems/',
#   'details': 'Caronae Systems',
#   'website': 'https://www.caronaesystems.com/?utm_source=start-up.ma',
#   'phone': 'tel:+212606343434',
#   'email': 'mailto:contact@caronaesystems.com'},
#  {'nameStratup': 'Caronae Systems',
#   'link': 'https://www.start-up.ma/liste-des-startups-au-maroc/caronae-systems/',
#   'details': 'Caronae Systems',
# ...

# %%
i=0
for Stratup in data :
  try:
    print(Stratup['email'])
  except:
    i=i+1
  
print(i)
#data[0]['email']
# Out:
# mailto:contact@caronaesystems.com
# mailto:contact@caronaesystems.com
# mailto:capitalquanta@gmail.com
# mailto:capitalquanta@gmail.com
# mailto:info@getpocketdoc.com
# mailto:info@getpocketdoc.com
# mailto:contact@cathedis.ma
# mailto:contact@cathedis.ma
# mailto:%20info@machaussure.ma
# mailto:%20info@machaussure.ma
# mailto:hello@koolskools.com
# mailto:hello@koolskools.com
# mailto:contact@datapathology.ma
# mailto:contact@datapathology.ma
# mailto:contact@nalidapower.com
# mailto:contact@nalidapower.com
# mailto:contact@mba.ma
# mailto:contact@mba.ma
# mailto:contact@lnkobrand.com
# mailto:contact@lnkobrand.com
# mailto:
# mailto:
# mailto:info@vitalcare.ma
# mailto:info@vitalcare.ma
# mailto:contact@outdooors.ma
# mailto:contact@outdooors.ma
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:contact@allogarant.com
# mailto:%20contact@shoelifer.com
# mailto:%20contact@shoelifer.com
# mailto:%20contact@shoelifer.com
# ...
